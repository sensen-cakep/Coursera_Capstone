# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods
# ### Applied Data Science Capstone by IBM

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# **Inkjet printers with ink tanks** have been gaining popularity in emerging countries like India. This is due to the appeal of lifetime ink that comes with the printer, tackling the perennial issue of frequent purchases of costly ink supplies.
#
# Epson is the market leader currently with HP catching up hard to gain market share. With limited go to market funds and retail costs, **how can HP effectively compete in different countries by being selective in the in-country choice of cities to promote their printers with targeted product placement?**
#
# For this project data science will be used to answer the above question. This will be a valuable tool for HP to gain market share rapidly without eroding profits unnecessarily to achieve it.
#
# **India will be the chosen country** as it is one of the main battlegrounds of the ink tank printer war.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# **Google Trends** with the following parameters is used to generate the choice of cities for analysis in India by the amount of search interest:
# * Search term **'tank printer'**
# * Time range will be from Jan 2016 to Jan 2021
# * Due to limitations of **pytrends API**, data will be imported for analysis using **Google Trends** generated csv file
#
# **GeoPy API** is used to generate latitude and longitude data for India and selected cities.
#
# **Foursquare API** is used to generate top 10 most common places where printers can be displayed and purchased within a 30km radius from city centre.

# %% [markdown]
# ### Create dataframe from Google Trends csv file
#
# Using the keywords "tank printer" the cities with search interest trend are listed and exported as a csv file.
#
# **pytrends API** unfortunately is unable to generate data by cities for India so it is not used in the this analysis.

# %%
#Google trends on keyword "tank printer" for India by city for last 5 years
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_e8b4efdc254b4e3cba32290b0c8527d1 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='cNcMJRv8jZBy0FmKCDeWSa8D0zLGO_AKueTuJC1FNXyd',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.ap-geo.objectstorage.service.networklayer.com')

body = client_e8b4efdc254b4e3cba32290b0c8527d1.get_object(Bucket='pythonbasicsfordatascienceproject-donotdelete-pr-8x8em0stoa3wot',Key='India_search_for_ tank_printer_Jan_2016_to_Jan_2021_from_Google_1Jan21.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_gtrend = pd.read_csv(body)
df_gtrend.head()
# Out:
#         City  trend_count
# 0    Kolkata          100
# 1  Ghaziabad           94
# 2      Noida           92
# 3     Mumbai           91
# 4    Gurgaon           84

# %% [markdown]
# ### Generate latitude and longitude data for the listed cities using GeoPy

# %%
# !pip install geopy # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.extra.rate_limiter import RateLimiter
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)

# %%
geolocator = Nominatim(user_agent="ny-application")
df_gtrend['gcode'] = df_gtrend['City'].apply(geolocator.geocode)
df_gtrend['lat'] = [g.latitude for g in df_gtrend['gcode']]
df_gtrend['long'] = [g.longitude for g in df_gtrend['gcode']]
df_gtrend
# Out:
#           City  trend_count  \
# 0      Kolkata          100
# 1    Ghaziabad           94
# 2        Noida           92
# 3       Mumbai           91
# 4      Gurgaon           84
# 5    New Delhi           62
# 6   Coimbatore           57
# 7    Bengaluru           53
# 8        Kochi           47
# 9      Chennai           46
# 10    Guwahati           38
# 11   Hyderabad           32
# 12     Lucknow           29
# 13        Pune           25
# 14   Ahmedabad           24
# 15     Raipura           19
# 16      Indore           16
#
#                                                 gcode        lat       long
# 0   (Kolkata, Howrah, West Bengal, India, (22.5414...  22.541418  88.357691
# 1   (Ghaziabad, Uttar Pradesh, India, (28.711241, ...  28.711241  77.444537
# 2   (Noida, Dadri, Gautam Buddha Nagar, Uttar Prad...  28.535633  77.391073
# 3   (Mumbai, Mumbai Suburban, Maharashtra, India, ...  19.075990  72.877393
# 4   (Gurgaon, Gurugram, Haryana, India, (28.428262...  28.428262  77.002700
# 5   (New Delhi, Delhi, India, (28.6138954, 77.2090...  28.613895  77.209006
# 6   (Coimbatore, Coimbatore North, Coimbatore Dist...  11.001812  76.962842
# 7   (Bengaluru, Bangalore North, Bangalore Urban, ...  12.979120  77.591300
# 8   (Kochi, Ernakulam district, Kerala, 682005, In...   9.931370  76.267376
# 9   (Chennai, Chennai District, Tamil Nadu, India,...  13.083694  80.270186
# 10  (Guwahati, Kamrup Metropolitan, 781015, India,...  26.180598  91.753943
# 11  (Hyderabad, Telangana, India, (17.38878595, 78...  17.388786  78.461065
# 12  (Lucknow, Sadar, Lucknow, Uttar Pradesh, 22601...  26.838100  80.934600
# 13  (Pune City, Pune District, Maharashtra, India,...  18.521428  73.854454
# 14  (Ahmedabad, Ahmadabad City Taluka, Ahmedabad D...  23.021624  72.579707
# 15  (Raipura, Raipura Tahsil, Panna, Madhya Prades...  23.900227  79.964884
# 16  (Indore, Madhya Pradesh, 452001, India, (22.72...  22.720362  75.868200

# %% [markdown]
# ### Use Folium to visualize the chosen India cities with the search trend ranking shown in pop up

# %% [markdown]
# Download all the dependencies that are required.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
# !pip install geopy # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt 

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# !pip install folium # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.1 MB/s  eta 0:00:01
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.11.0
# Libraries imported.

# %% [markdown]
# Get the geographical coordinates of India.

# %%
address = 'India'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of India are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of India are 22.3511148, 78.6677428.

# %% [markdown]
# Visualize India and the selected cities from Google Trends.

# %%
# !pip install folium
import folium

# Create India map
map_india = folium.Map(location=[latitude, longitude], zoom_start=5)

# Add markers
for lat, lng, city, trend_count in zip(df_gtrend['lat'], df_gtrend['long'], df_gtrend['City'], df_gtrend['trend_count']):
    label = '{} {}'.format(city, trend_count)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=7,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_india)  
    
map_india
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_58af50ca11be4d68ae1be8b1d12df01b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_58af50ca11be4d68ae1be8b1d12df01b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_58af50ca11be4d68ae1be8b1d12df01b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_58af50ca11be4d68ae1be8b1d12df01b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B22.3511148%2C%2078.6677428%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### Generate common places where printers can be displayed and purhcased in a 30km radius around the city centre using Foursquare
#
# The following Foursquare categories are chosen to narrow down the data generated:
# * Shopping Mall, 4bf58dd8d48988d1fd941735
# * Shopping Plaza, 5744ccdfe4b0c0459246b4dc
# * Outlet Mall, 5744ccdfe4b0c0459246b4df
# * Outlet Store, 52f2ab2ebcbc57f1066b8b35
# * Paper/Office Supplies Store, 4bf58dd8d48988d121951735
# * Electronics Store, 4bf58dd8d48988d122951735
# * Department Store, 4bf58dd8d48988d1f6941735
# * Bookstore, 4bf58dd8d48988d114951735

# %% [markdown]
# Define Foursquare Credentials and Version.

# %%
CLIENT_ID = 'PXSRO5SKINAAQJNPRVFCCV1HRRTXJFRJ2LTMUSUXQ4NYXF03' # your Foursquare ID
CLIENT_SECRET = 'XBU45UFEDM1PLUXZQF0IPD5K0UPKLNG4AFIFQQBP034V04AFt' # your Foursquare Secret
ACCESS_TOKEN = '0SLF0JB3S5CMYQKWZO3GKBCDKNOOI2MZFJO1IVVWWVSAMOYE' # your FourSquare Access Token
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PXSRO5SKINAAQJNPRVFCCV1HRRTXJFRJ2LTMUSUXQ4NYXF03
# CLIENT_SECRET:XBU45UFEDM1PLUXZQF0IPD5K0UPKLNG4AFIFQQBP034V04AFt

# %% [markdown]
# Explore the first city in dataframe as an example.

# %% [markdown]
# Get the city's name and geographical location.

# %%
city_latitude = df_gtrend.loc[0, 'lat'] # city latitude value
city_longitude = df_gtrend.loc[0, 'long'] # city longitude value

city_name = df_gtrend.loc[0, 'City'] # city name

print('Latitude and longitude values of {} are {}, {}.'.format(city_name, 
                                                               city_latitude, 
                                                               city_longitude))
# Out:
# Latitude and longitude values of Kolkata are 22.5414185, 88.35769124388872.

# %% [markdown]
# Now, let's get the top 100 venues within a radius of 30km.

# %% [markdown]
# First, let's create the GET request URL.

# %%
# Form Foursquare URL with categories where printers can likely be purchased
LIMIT = 100

radius = 30000

printer_categories = '4bf58dd8d48988d1fd941735,5744ccdfe4b0c0459246b4dc,5744ccdfe4b0c0459246b4df,52f2ab2ebcbc57f1066b8b35,4bf58dd8d48988d121951735,4bf58dd8d48988d122951735,4bf58dd8d48988d1f6941735,4bf58dd8d48988d114951735'

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&oauth_token={}&radius={}&limit={}'.format(
       CLIENT_ID,
       CLIENT_SECRET,
       VERSION,
       city_latitude,
       city_longitude,
       printer_categories,
       ACCESS_TOKEN,
       radius,
       LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=PXSRO5SKINAAQJNPRVFCCV1HRRTXJFRJ2LTMUSUXQ4NYXF03&client_secret=XBU45UFEDM1PLUXZQF0IPD5K0UPKLNG4AFIFQQBP034V04AFt&v=20180605&ll=22.5414185,88.35769124388872&categoryId=4bf58dd8d48988d1fd941735,5744ccdfe4b0c0459246b4dc,5744ccdfe4b0c0459246b4df,52f2ab2ebcbc57f1066b8b35,4bf58dd8d48988d121951735,4bf58dd8d48988d122951735,4bf58dd8d48988d1f6941735,4bf58dd8d48988d114951735&oauth_token=0SLF0JB3S5CMYQKWZO3GKBCDKNOOI2MZFJO1IVVWWVSAMOYE&radius=30000&limit=100'

# %% [markdown]
# Send the GET request and examine the results.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ff08032dad389062d7cd86b'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Kolkata',
#   'headerFullLocation': 'Kolkata',
#   'headerLocationGranularity': 'city',
#   'query': 'mall',
#   'totalResults': 43,
#   'suggestedBounds': {'ne': {'lat': 22.81141877000027,
#     'lng': 88.64947921959752},
#    'sw': {'lat': 22.27141822999973, 'lng': 88.06590326817992}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5274b7f111d2b513631071a5',
#        'name': 'Quest Mall',
#        'location': {'address': '33, Syed Aamir Ali Ave',
#         'lat': 22.539068009925764,
#         'lng': 88.36552456686483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539068009925764,
#           'lng': 88.36552456686483}],
#         'distance': 846,
#         'postalCode': '700017',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['33, Syed Aamir Ali Ave',
#          'Kolkata 700017',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5274b7f111d2b513631071a5-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb3427e715eef3bdd1286bb',
#        'name': 'South City Mall',
#        'location': {'address': '375, Prince Anwar Shah Rd',
#         'lat': 22.501757795323314,
#         'lng': 88.36172644899912,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.501757795323314,
#           'lng': 88.36172644899912}],
#         'distance': 4434,
#         'postalCode': '700068',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['375, Prince Anwar Shah Rd',
#          'Kolkata 700068',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57876972'}},
#       'referralId': 'e-0-4bb3427e715eef3bdd1286bb-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56042ace498efedb770e3dcc',
#        'name': 'Acropolis Mall',
#        'location': {'address': '1858/1, Rajdanga Main Rd',
#         'lat': 22.51482318507145,
#         'lng': 88.3932354886466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.51482318507145,
#           'lng': 88.3932354886466}],
#         'distance': 4703,
#         'postalCode': '700107',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['1858/1, Rajdanga Main Rd',
#          'Kolkata 700107',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56042ace498efedb770e3dcc-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee95bfe24d20a1960e7314',
#        'name': 'City Centre',
#        'location': {'address': '3rd Avenue, Block DC, Sector 1, Salt Lake',
#         'lat': 22.587921364007034,
#         'lng': 88.4080982208252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.587921364007034,
#           'lng': 88.4080982208252}],
#         'distance': 7324,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['3rd Avenue, Block DC, Sector 1, Salt Lake',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee95bfe24d20a1960e7314-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c333482a0ced13af334166e',
#        'name': 'Mani Square Mall',
#        'location': {'address': '164/1, Maniktala Main Rd',
#         'lat': 22.57782292205015,
#         'lng': 88.40059141088483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.57782292205015,
#           'lng': 88.40059141088483}],
#         'distance': 5989,
#         'postalCode': '700054',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['164/1, Maniktala Main Rd',
#          'Kolkata 700054',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c333482a0ced13af334166e-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c025188310fc9b6bc47c461',
#        'name': 'Forum Mall',
#        'location': {'address': '10/3, Elgin Rd',
#         'lat': 22.53860126968133,
#         'lng': 88.35111737251282,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53860126968133,
#           'lng': 88.35111737251282}],
#         'distance': 745,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['10/3, Elgin Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c025188310fc9b6bc47c461-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1933b0e4b0a339fac6e75e',
#        'name': 'Avani Riverside Mall',
#        'location': {'address': '32, Jagat Banerjee Ghat Rd',
#         'lat': 22.563240625270023,
#         'lng': 88.323724824009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.563240625270023,
#           'lng': 88.323724824009}],
#         'distance': 4253,
#         'postalCode': '711102',
#         'cc': 'IN',
#         'city': 'Hāora',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['32, Jagat Banerjee Ghat Rd',
#          'Hāora 711102',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1933b0e4b0a339fac6e75e-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be9836961aca593b89b8200',
#        'name': 'City Centre 2',
#        'location': {'address': 'Plot no. AA-IID, JK no.11, Mouza: Noapara, New Town',
#         'lat': 22.622515346922857,
#         'lng': 88.45027525403412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.622515346922857,
#           'lng': 88.45027525403412}],
#         'distance': 13116,
#         'postalCode': '700157',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Plot no. AA-IID, JK no.11, Mouza: Noapara, New Town',
#          'Kolkata 700157',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be9836961aca593b89b8200-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7497178998ed82a40d2bab',
#        'name': 'Starmark',
#        'location': {'address': 'Mani Square Mall',
#         'lat': 22.584800007542476,
#         'lng': 88.39935655871606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.584800007542476,
#           'lng': 88.39935655871606}],
#         'distance': 6454,
#         'postalCode': '700054',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Mani Square Mall',
#          'Kolkata 700054',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7497178998ed82a40d2bab-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf2b0bd82002d7fbdd3d0bb',
#        'name': 'Sir Stuart Hogg Market',
#        'location': {'address': 'Lindsay St',
#         'lat': 22.5600012727137,
#         'lng': 88.3525744443409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5600012727137,
#           'lng': 88.3525744443409}],
#         'distance': 2134,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Lindsay St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf2b0bd82002d7fbdd3d0bb-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5b43bad164da2b277a3995',
#        'name': 'Big Bazaar',
#        'location': {'address': '1, Beliaghata Rd',
#         'lat': 22.565918736488236,
#         'lng': 88.36963534355162,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.565918736488236,
#           'lng': 88.36963534355162}],
#         'distance': 2991,
#         'postalCode': '700014',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['1, Beliaghata Rd',
#          'Kolkata 700014',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5b43bad164da2b277a3995-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf2949d7f2aef3b8ec7392a',
#        'name': 'College Street Market',
#        'location': {'address': 'College St',
#         'crossStreet': 'Mahatma Gandhi Rd',
#         'lat': 22.576320637232534,
#         'lng': 88.36363117811548,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.576320637232534,
#           'lng': 88.36363117811548}],
#         'distance': 3932,
#         'postalCode': '700073',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['College St (Mahatma Gandhi Rd)',
#          'Kolkata 700073',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf2949d7f2aef3b8ec7392a-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcf06c8cc8cd13a0e33c5cf',
#        'name': 'Dakshinapan Shopping Complex',
#        'location': {'address': '2, Gariahat Rd',
#         'crossStreet': 'Near Dhakuria Bridge',
#         'lat': 22.50874853415032,
#         'lng': 88.3666005339919,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.50874853415032,
#           'lng': 88.3666005339919}],
#         'distance': 3750,
#         'postalCode': '700068',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['2, Gariahat Rd (Near Dhakuria Bridge)',
#          'Kolkata 700068',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcf06c8cc8cd13a0e33c5cf-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f780b94e4b08f9be626d425',
#        'name': 'Spencers',
#        'location': {'address': 'Axis Mall',
#         'lat': 22.579303026695015,
#         'lng': 88.46027782761654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.579303026695015,
#           'lng': 88.46027782761654}],
#         'distance': 11357,
#         'postalCode': '700156',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Axis Mall',
#          'Kolkata 700156',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f780b94e4b08f9be626d425-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505b2f0ce4b02f88a6cef59b',
#        'name': 'Diamond Plaza Mall',
#        'location': {'address': '68, Jessore Rd',
#         'lat': 22.615516268438355,
#         'lng': 88.4125292301178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.615516268438355,
#           'lng': 88.4125292301178}],
#         'distance': 9990,
#         'postalCode': '700055',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['68, Jessore Rd',
#          'Kolkata 700055',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-505b2f0ce4b02f88a6cef59b-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf3eec43f86c9b629a0b21c',
#        'name': 'C3',
#        'location': {'address': 'City Centre Mall',
#         'lat': 22.587263110243896,
#         'lng': 88.40732308849229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.587263110243896,
#           'lng': 88.40732308849229}],
#         'distance': 7216,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['City Centre Mall',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf3eec43f86c9b629a0b21c-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db2a089f7b12ee8facdb145',
#        'name': 'Metro Plaza',
#        'location': {'address': '1, Ho Chi Minh Sarani',
#         'lat': 22.547103259048296,
#         'lng': 88.34906280040741,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.547103259048296,
#           'lng': 88.34906280040741}],
#         'distance': 1089,
#         'postalCode': '700071',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['1, Ho Chi Minh Sarani',
#          'Kolkata 700071',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db2a089f7b12ee8facdb145-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd17ae37f56a143f397d4a6',
#        'name': "Spencer's Hyper",
#        'location': {'address': '145, Rash Behari Ave',
#         'lat': 22.519152585285212,
#         'lng': 88.36153573639466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.519152585285212,
#           'lng': 88.36153573639466}],
#         'distance': 2509,
#         'postalCode': '700029',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['145, Rash Behari Ave',
#          'Kolkata 700029',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd17ae37f56a143f397d4a6-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '520849bf2fc6a9374a677cf7',
#        'name': 'Lake Mall',
#        'location': {'address': '104, Rash Behari Ave',
#         'lat': 22.516610596676667,
#         'lng': 88.34895014762878,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.516610596676667,
#           'lng': 88.34895014762878}],
#         'distance': 2904,
#         'postalCode': '700029',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['104, Rash Behari Ave',
#          'Kolkata 700029',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520849bf2fc6a9374a677cf7-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4d0908d6f3224be89797a6',
#        'name': 'Simpark Mall',
#        'location': {'address': 'S.S. Hogg Market',
#         'crossStreet': 'Lindsay Street',
#         'lat': 22.5595394767376,
#         'lng': 88.35273092727438,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5595394767376,
#           'lng': 88.35273092727438}],
#         'distance': 2080,
#         'postalCode': '700001',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['S.S. Hogg Market (Lindsay Street)',
#          'Kolkata 700001',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4d0908d6f3224be89797a6-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51ae534c498edd0f1b68a21d',
#        'name': 'STORY',
#        'location': {'address': '8, Elgin Rd',
#         'lat': 22.53826851013981,
#         'lng': 88.35209467134058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.53826851013981,
#           'lng': 88.35209467134058}],
#         'distance': 673,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['8, Elgin Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '89944207'}},
#       'referralId': 'e-0-51ae534c498edd0f1b68a21d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d36a80f10248cfa930c87cf',
#        'name': 'Starmark',
#        'location': {'address': 'Emami Market, 3, Lord Sinha Rd',
#         'lat': 22.543550237030196,
#         'lng': 88.34885188040607,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.543550237030196,
#           'lng': 88.34885188040607}],
#         'distance': 939,
#         'postalCode': '700071',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Emami Market, 3, Lord Sinha Rd',
#          'Kolkata 700071',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d36a80f10248cfa930c87cf-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4bc075962d6dcbfda18558',
#        'name': 'AC Market',
#        'location': {'address': 'Shakespeare Sarani',
#         'lat': 22.545719690655293,
#         'lng': 88.34925497604009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.545719690655293,
#           'lng': 88.34925497604009}],
#         'distance': 990,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['Shakespeare Sarani', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4bc075962d6dcbfda18558-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cde4c41db125481e3f72fce',
#        'name': 'E-Mall',
#        'location': {'address': 'Ganesh Chandra Ave',
#         'lat': 22.56695478949371,
#         'lng': 88.35487421222419,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.56695478949371,
#           'lng': 88.35487421222419}],
#         'distance': 2857,
#         'postalCode': '700072',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Ganesh Chandra Ave',
#          'Kolkata 700072',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cde4c41db125481e3f72fce-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e82dffb754a3055e15f2a90',
#        'name': 'Apple iStore',
#        'location': {'address': '57A, Park St',
#         'lat': 22.552443984519737,
#         'lng': 88.35319876670836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.552443984519737,
#           'lng': 88.35319876670836}],
#         'distance': 1311,
#         'postalCode': '700016',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['57A, Park St',
#          'Kolkata 700016',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e82dffb754a3055e15f2a90-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f3fc94befd54d528e1e0877',
#        'name': 'Hafele Design Centre Kolkata',
#        'location': {'address': 'No. 1/1A , PS Pace Premises, Mahendra Roy Lane, Topsia Gobra',
#         'lat': 22.5399918,
#         'lng': 88.3802758,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5399918,
#           'lng': 88.3802758}],
#         'distance': 2327,
#         'postalCode': '700046',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['No. 1/1A , PS Pace Premises, Mahendra Roy Lane, Topsia Gobra',
#          'Kolkata 700046',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '594700530'}},
#       'referralId': 'e-0-5f3fc94befd54d528e1e0877-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '520cd26611d2285d21714919',
#        'name': 'Big Bazaar',
#        'location': {'address': 'Lake Mall',
#         'lat': 22.516650240516316,
#         'lng': 88.34904670715332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.516650240516316,
#           'lng': 88.34904670715332}],
#         'distance': 2896,
#         'postalCode': '700029',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Lake Mall',
#          'Kolkata 700029',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-520cd26611d2285d21714919-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be982bb947820a1e916b6db',
#        'name': 'Big Bazaar',
#        'location': {'address': 'Sector 2, Salt Lake',
#         'lat': 22.58354830847126,
#         'lng': 88.41754301259155,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.58354830847126,
#           'lng': 88.41754301259155}],
#         'distance': 7736,
#         'postalCode': '700091',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Sector 2, Salt Lake',
#          'Kolkata 700091',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be982bb947820a1e916b6db-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e42e234b3ad9c237e87181e',
#        'name': 'Reliance Digital',
#        'location': {'address': 'V. I. P. Rd',
#         'lat': 22.572724967265597,
#         'lng': 88.3641529083252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.572724967265597,
#           'lng': 88.3641529083252}],
#         'distance': 3547,
#         'postalCode': '700052',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['V. I. P. Rd',
#          'Kolkata 700052',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e42e234b3ad9c237e87181e-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfd2e7b2b83b7139fa7a998',
#        'name': 'Metropolis Mall',
#        'location': {'address': 'Hiland Park',
#         'lat': 22.48319670950164,
#         'lng': 88.39080333709717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.48319670950164,
#           'lng': 88.39080333709717}],
#         'distance': 7321,
#         'postalCode': '700094',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Hiland Park',
#          'Kolkata 700094',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfd2e7b2b83b7139fa7a998-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f6c6e1de4b032eb620614d2',
#        'name': 'Brand Factory',
#        'location': {'address': 'Lee Rd',
#         'lat': 22.539153716715752,
#         'lng': 88.34939539432526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.539153716715752,
#           'lng': 88.34939539432526}],
#         'distance': 889,
#         'postalCode': '700020',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Lee Rd',
#          'Kolkata 700020',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f6c6e1de4b032eb620614d2-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e782f076365ce8463b6ab48',
#        'name': 'Reliance Digital',
#        'location': {'address': 'Avani Riverside Mall',
#         'lat': 22.564680303198223,
#         'lng': 88.32128047943115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.564680303198223,
#           'lng': 88.32128047943115}],
#         'distance': 4551,
#         'postalCode': '711102',
#         'cc': 'IN',
#         'city': 'Hāora',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Avani Riverside Mall',
#          'Hāora 711102',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e782f076365ce8463b6ab48-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56042bf7498e56d1e0fde365',
#        'name': 'Shoppers Stop',
#        'location': {'address': 'Acropolis Mall',
#         'lat': 22.514737412291872,
#         'lng': 88.39320659637451,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.514737412291872,
#           'lng': 88.39320659637451}],
#         'distance': 4707,
#         'postalCode': '700107',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Acropolis Mall',
#          'Kolkata 700107',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56042bf7498e56d1e0fde365-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7f41ece5fa8111dfddad21',
#        'name': 'Great Eastern',
#        'location': {'address': 'Kakurgachi',
#         'crossStreet': 'P-273,Manictala Main Road',
#         'lat': 22.58013515367942,
#         'lng': 88.38811039924622,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.58013515367942,
#           'lng': 88.38811039924622}],
#         'distance': 5324,
#         'postalCode': '700054',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Kakurgachi (P-273,Manictala Main Road)',
#          'Kolkata 700054',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7f41ece5fa8111dfddad21-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5102aca2e4b077344fd5b9c4',
#        'name': 'Avishar Shopping Mall',
#        'location': {'address': '369/4, Eastern Metropolitan Bypass',
#         'lat': 22.50411230946722,
#         'lng': 88.4000301361084,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.50411230946722,
#           'lng': 88.4000301361084}],
#         'distance': 6016,
#         'postalCode': '700099',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['369/4, Eastern Metropolitan Bypass',
#          'Kolkata 700099',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5102aca2e4b077344fd5b9c4-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff6b1d3e4b0cc077db9e845',
#        'name': 'Office Linc',
#        'location': {'address': 'City Centre Mall',
#         'lat': 22.5880006107045,
#         'lng': 88.40818405151367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.5880006107045,
#           'lng': 88.40818405151367}],
#         'distance': 7336,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['City Centre Mall',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d121951735',
#          'name': 'Paper / Office Supplies Store',
#          'pluralName': 'Paper / Office Supplies Stores',
#          'shortName': 'Office Supplies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/papergoods_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff6b1d3e4b0cc077db9e845-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea04a8dd5fb7087ec5d74f4',
#        'name': 'Imagine',
#        'location': {'address': 'City Center Mall',
#         'lat': 22.588025375288108,
#         'lng': 88.40818405151367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.588025375288108,
#           'lng': 88.40818405151367}],
#         'distance': 7338,
#         'postalCode': '700064',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['City Center Mall',
#          'Kolkata 700064',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea04a8dd5fb7087ec5d74f4-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '596b7e89a22db76efcb8cdfa',
#        'name': 'Central Mall',
#        'location': {'address': 'Street Number 95, Action Area 1B, Newtown',
#         'lat': 22.58294854254236,
#         'lng': 88.4587812423706,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.58294854254236,
#           'lng': 88.4587812423706}],
#         'distance': 11373,
#         'postalCode': '700156',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Street Number 95, Action Area 1B, Newtown',
#          'Kolkata 700156',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-596b7e89a22db76efcb8cdfa-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c14945c77cea59355e6d060',
#        'name': 'Pantaloons',
#        'location': {'address': 'City Centre 2',
#         'lat': 22.622432482346067,
#         'lng': 88.45042665148057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.622432482346067,
#           'lng': 88.45042665148057}],
#         'distance': 13121,
#         'postalCode': '700136',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['City Centre 2',
#          'Kolkata 700136',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c14945c77cea59355e6d060-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50fe7fb8e4b0c9eec09b7dd7',
#        'name': 'Big Bazaar',
#        'location': {'address': 'Wood Square Mall',
#         'lat': 22.43204811133225,
#         'lng': 88.42028331201263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.43204811133225,
#           'lng': 88.42028331201263}],
#         'distance': 13772,
#         'postalCode': '700103',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['Wood Square Mall',
#          'Kolkata 700103',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50fe7fb8e4b0c9eec09b7dd7-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daa7c3b6e81162ae7d89e1b',
#        'name': 'Axis Mall',
#        'location': {'address': 'CF Block, Newtown',
#         'crossStreet': 'Rajarhat',
#         'lat': 22.579243574798344,
#         'lng': 88.45993995666504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.579243574798344,
#           'lng': 88.45993995666504}],
#         'distance': 11323,
#         'postalCode': '700156',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['CF Block, Newtown (Rajarhat)',
#          'Kolkata 700156',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4daa7c3b6e81162ae7d89e1b-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dec52f0814d76ba54188b14',
#        'name': 'South City Towers',
#        'location': {'address': '375, Prince Anwar Shah Rd',
#         'lat': 22.499466424402296,
#         'lng': 88.35920313444731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.499466424402296,
#           'lng': 88.35920313444731}],
#         'distance': 4672,
#         'postalCode': '700068',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['375, Prince Anwar Shah Rd',
#          'Kolkata 700068',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4d954b06a243a5684965b473',
#          'name': 'Residential Building (Apartment / Condo)',
#          'pluralName': 'Residential Buildings (Apartments / Condos)',
#          'shortName': 'Residential',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dec52f0814d76ba54188b14-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53099e5c11d2b7b9393299c4',
#        'name': 'Nelso Technology Pvt. Ltd.',
#        'location': {'address': 'P-96, Sreebhumi,',
#         'crossStreet': 'Ichapur, 24PGS(N)',
#         'lat': 22.799090023378614,
#         'lng': 88.37754249572754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.799090023378614,
#           'lng': 88.37754249572754}],
#         'distance': 28756,
#         'postalCode': '743144',
#         'cc': 'IN',
#         'city': 'Kolkata',
#         'state': 'West Bengal',
#         'country': 'India',
#         'formattedAddress': ['P-96, Sreebhumi, (Ichapur, 24PGS(N))',
#          'Kolkata 743144',
#          'West Bengal',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85318068'}},
#       'referralId': 'e-0-53099e5c11d2b7b9393299c4-42'}]}]}}

# %% [markdown]
# All the information is in the items key. Use the get_category_type function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Clean the json and structure it into a pandas dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                name     categories        lat        lng
# 0        Quest Mall  Shopping Mall  22.539068  88.365525
# 1   South City Mall  Shopping Mall  22.501758  88.361726
# 2    Acropolis Mall  Shopping Mall  22.514823  88.393235
# 3       City Centre  Shopping Mall  22.587921  88.408098
# 4  Mani Square Mall  Shopping Mall  22.577823  88.400591

# %% [markdown]
# How many venues were returned by Foursquare?

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 43 venues were returned by Foursquare.
